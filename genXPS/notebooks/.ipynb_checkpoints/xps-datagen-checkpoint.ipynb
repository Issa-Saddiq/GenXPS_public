# %%
import os 
import csv
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
def create_random_compositions(elements, num_of_composition):
    '''
    Creates the random compositions for the training data
    Args
        elements: The elements to include in the training set
        num_of_compositions: the number of training data examples to create
    Returns:
        composition: a dictionary of the emements present and their percentages
    '''
    bool_list = [True, False]
    is_present = []
    composition =[]
    for i in range(num_of_composition):
        tmp = []
        for j in range(len(elements)):
            tmp.append(random.choice(bool_list))

        if True not in tmp:
            tmp[random.randint(0,len(elements)-1)] = True
        is_present.append(tmp)

    for i in range(num_of_composition):
        tmp = {}
        total = 0
        for j in range(len(elements)):
            if not is_present[i][j]:
                continue
            x =  random.random()
            tmp[elements[j]] = x
            total += x

        tmp = {k:(v/total) for k,v in tmp.items()}
        composition.append(tmp)

    return composition


def chop_and_shift(spectrum, ranges, max_shift):
    '''
    Cuts out the regions of the spectrum from the main spectrum and applys a random shift +/- to the entire spectrum
    Args:
        spectrum
        ranges: the indices of the ranges to take out of the spectrum
        max_shift: maximum number of indices by which the data can shift (set to zero for no shift allowed)
    Returns:
        spectrum
    '''

    indices = []
    shift = random.randint(-max_shift, max_shift)
    for i in range(len(ranges)):
        inds = list(range(ranges[i][0]+shift, ranges[i][1]+shift))
        for ind in inds:
            indices.append(ind)
    return spectrum[indices]


def apply_horizontal_shift(spectrum, max_shift):
    '''
    Applies a random horizontal shift to the entire spectrum sequence.
    Args:
        spectrum
        max_shift: maximum number of indices by which the data can shift (set to zero for no shift allowed)
    Returns:
        shifted_spectrum
    '''
    shift = random.randint(-max_shift, max_shift)
    # Create an array of zeros with the same length as the original spectrum
    shifted_spectrum = np.zeros_like(spectrum)

    if shift > 0:
        # Shift to the right
        shifted_spectrum[shift:] = spectrum[:-shift]
    elif shift < 0:
        # Shift to the left
        shifted_spectrum[:shift] = spectrum[-shift:]
    else:
        # No shift, return the original spectrum
        shifted_spectrum = spectrum.copy()

    shifted_spectrum = shifted_spectrum[:len(spectrum)]


    return shifted_spectrum

def get_spec(path_to_file):
    '''
    Extract the spectra coordinates from excel files
    '''
    df_f = pd.read_excel(path_to_file, sheet_name='All')
    return np.array(df_f['CPS'])[:2210]

def get_label(path_to_file):
    '''
    Extract the lables from excel files
    '''
    spreadsheet_f = pd.ExcelFile(path_to_file)
    df_f = pd.read_excel(spreadsheet_f)
    labels = np.array(df_f['Number'])
    return np.nan_to_num(labels)

def get_label_dict(path_to_file):
    '''
    Extract the list of functional groups
    '''
    spreadsheet_f = pd.ExcelFile(path_to_file)
    df_f = pd.read_excel(spreadsheet_f)
    return list(df_f['Functional groups'])

def label_converter(label):
    '''
    Converts the encoded label lists into a readable format

    '''
    CEL_path = os.path.join(data_path, 'cellulose (CEL)', 'CEL_FG.xlsx') 
    label_dict = get_label_dict(CEL_path)
    fg_counts = []
    fg_count = "" 

    for i, e in enumerate(label):
        if pd.isna(e):
            e = 0
        if e != 0.0:
            fg_count = f'{e:.2f}  {label_dict[i]}'
            fg_counts.append(fg_count)

    return fg_counts

def open_all_xps_files(data_path, elements=None):
    '''
    Open and read in the data from the experimental spectra
    Args:
        data_path: where the data is
        elements: the individual polymers to use as source data, if none then all directories available are used
    Returns:
         spectral_data: list of the polymer spectra
         label_data: list of the labels for each polymer
         ids: list of the polymer ids
        
    '''
    if not elements:
        all_folders = os.listdir(data_path)
    else:
        all_folders = [e for e in elements]
    spectral_data = {}
    label_data = {}
    ids = []
    print('Folders', all_folders)
    for folder in all_folders:
        folder_spec_format = folder[:folder.rfind(' (')]
        folder_label_format = folder[folder.rfind(' (') + 2:folder.rfind(')')]

        filename_spec = folder_spec_format + '.xlsx'
        filename_label = folder_label_format + '_FG.xlsx'

        spec_path = os.path.join(data_path, folder, filename_spec)
        label_path = os.path.join(data_path, folder, filename_label)

        if not os.path.isfile(label_path):
            filename_label = folder + '_FG.xlsx'
            label_path = os.path.join(data_path, folder, filename_label)

        if not os.path.isfile(spec_path):
            filename_spec = folder + '.xlsx'
            spec_path = os.path.join(data_path, folder, filename_spec)

        if os.path.isfile(os.path.join(data_path, folder, filename_spec)) and \
            os.path.isfile(os.path.join(data_path, folder,  filename_label)):
            file_spec = os.path.join(data_path, folder, filename_spec)
            file_label = os.path.join(data_path, folder, filename_label)
            data_spec = []
            data_label = []
            print('Material ID:', file_spec)
            data_spec = get_spec(file_spec)
            data_label = get_label(file_label)

            data_label = np.nan_to_num(data_label)
            ids.append(folder)
        spectral_data[folder] = data_spec
        label_data[folder] = data_label
    return spectral_data, label_data, ids

def generate_mixture_xps(all_spectra, all_labels, sample_ids, max_materials, augment, debug=False):
    '''
    Returns:
        spectrum: a fractionally weighted combination of the spectra
        labels: a fractionally weighted combination of the labels
    '''
    
    labels = np.zeros(shape=all_labels['cellulose (CEL)'].shape)
    spectrum = np.zeros(shape=all_spectra['cellulose (CEL)'].shape)

    num_materials = random.randint(1, max_materials)
    fractions = np.random.rand(num_materials)
    fractions = fractions/np.sum(fractions)
    for _i in range(num_materials):
        material_id = sample_ids[random.randint(0, len(sample_ids)-1)]

        added_spectrum = apply_horizontal_shift(all_spectra[material_id], augment['max_shift'] )
        if spectrum.shape != added_spectrum.shape:
            added_spectrum = added_spectrum[:spectrum.shape[0]]
        spectrum += apply_horizontal_shift(all_spectra[material_id], augment['max_shift'] ) * fractions[_i]
        labels += all_labels[material_id] * fractions[_i]
    if debug:
        print(fractions)
        
    return spectrum, labels, fractions

# %% [markdown]
# ## Load the data
#
# Tell the code where to go to find the data

# %%
data_path = Path("../data/experimental_data")

# %% [markdown]
# ## Run the script
#
# Here there are a few variables to set:
#
# * `polymers` - this is the list of the directories that you want to explore. If left balnk the code automatically uses all polymers in the `data_path`
# * `data_size` - the number of training examples to create
# * `augment_information` - how to augment the data, `max_shift` refers to the maximum amount the data can be shifted up or down in energy, `ranges` the indices from the data to use. Currently just use the defaults provided
# * `max_materials_per_sample` - how many polymers to mix for a sprectrum at most. 2 is a good default for now.

# %%
all_polymers = os.listdir(data_path)
polymers = all_polymers[0:106]

data_size = 10
augment_information = {'max_shift': 100}
max_materials_per_sample = 3

labels = []
spectra = []
fra = []



xps_data = open_all_xps_files(data_path=data_path, elements=polymers)
for i in range(data_size):
    spec, lab, frac = generate_mixture_xps(xps_data[0], xps_data[1], xps_data[2], max_materials_per_sample, augment_information, debug=False)
    labels.append(lab)
    spectra.append(spec)
    fra.append(frac)
# Out:
# Folders ['poly(acrylamide) (PAM)', 'poly(tetrafluoroethylene) (PTFE)', 'poly(hexamethylene sulphone) (PHMS)', 'poly(ether sulphone) (PES)', 'p-Quaterphenyl [poly(phenylene) oligomer]', 'poly(methacrylonitrile) (PMAN)', 'poly(propylene) (PP)', 'poly(ether imide) (Ultem 1000) (ULT)', 'Poly(2-chloroethyl methacrylate) (PCEMA)', 'poly(vinyl methyl ether) (PVME)', 'poly(vinylidine chloride) (PVdC)', 'poly(ethylene sulphide) (PETHS)', 'poly(a-methylstryene) (PαMS)', 'poly(phenylene sulphide) (PPS)', 'Nylon 6 (N6)', 'poly(2-ethyl-2-oxazoline) (PEOx)', 'poly(propylene glycol) (PPG)', 'poly(tert-butyl methacrylate) (PtBMA)', 'poly(phenoxyphosphazine) (PPP)', 'poly(orthoester) based on trans-cyclohexanedimethanol (POECDM)', 'poly(methacrylic acid) (PMAA)', 'poly(methyl methacrylate) (PMMA)', 'poly(d,l-lactide) (PL)', 'poly(caprolactone) (PCL)', 'poly(acrylonitrile) (PAN)', 'poly(allylamine hydrochloride) (PAAMC)', 'poly(trifluoroethyl acrylate) (PTFEA)', 'poly(vinyl alcohol) (PVA)', 'poly(vinyl acetate) (PVAc)', 'poly(4-hydroxystyrene) (PHS)', 'Nylon 6,6 (N66)', 'poly(tetramethylene glycol) (PTMG)', 'poly(methyl acrylate) (PMA)', 'poly(cis-butadiene) (PcBD)', 'poly(vinyl trifluoroacetate) (PVTFA)', 'poly(ethylene terephthalate) (PET)', 'poly(diallyl isophthalate) (PDAiP)', "N,N'-Diphenyl-1,4-phenylenediamine [poly(aniline) oligomer]", 'poly(4-methyl-1-pentene) (PMP)', 'poly(4-methylstyrene) (P4MS)', 'poly(2-vinylnaphthalene) (PVN)', 'poly(3-hydroxybutyrate) (PHB)', 'poly(n-butyl methacrylate) (PnBMA)', 'poly(vinyl propionate) (PVP)', 'cellulose triacetate (CTA)', 'poly(ethyl acrylate) (PEA)', 'poly(vinyl isobutyl ether) (PViBE)', 'poly(pheonylmethylsiloxane) (PPMS)', 'poly(vinyl chloride) (PVC)', 'cellulose trinitrate (CTN)', 'poly(vinyl ethyl ketone) (PVEK)', 'poly(vinyl laurate) (PVL)', 'poly(4-chlolorostyrene) (P4CS)', 'poly(isobutylene) (PIB)', 'poly(4-methoxystyrene) (PMS)', 'poly(dimethylsiloxane) (PDMS)', 'poly(urethane) (PU)', 'poly(trans-isoprene) (PtI)', 'poly(lauryl methacrylate) (PLMA)', 'poly(chloroprene) (PCP)', 'poly(styrene) (PS)', 'poly(4-nitrostyrene) (PNS)', 'poly(ethylene adipate) (PEAd)', 'poly(vinyl methyl ketone) (PVMK)', 'poly(2-vinylpyridine) (P2VP)', 'poly(bisphenol A carbonate) (PBAC)', 'poly(9-vinylcarbazole) (P9VC)', 'poly(vinyl ethyl ether) (PVEE)', 'poly(hydroxyethyl methacrylate) (PHEMA)', 'poly(cis-isoprene) (PcI)', 'poly(ethylene-co-maleic anhydride) (PECMA)', 'poly(ethyleneimine) (PEI)', 'poly(1-butene) (PB)', 'poly(2-chlorostyrene) (P2CS)', 'poly(vinyl fluoride) (PVF)', 'Nylon 12 (N12)', 'poly(acetylacetoxyethyl methacrylate) (PAAEMA)', 'Hydroxypropylycellulose (HPCEL)', 'poly(sodium 4-styrenesulphonate) (PSS)', 'poly(diallyl phthalate) (PDAP)', 'poly(ether ether ketone) (PEEK)', 'poly(pivalolactone) (PPL)', 'poly(methyl isopropenyl ketone) (PMIK)', 'poly(ethylene), high density (HDPE)', 'poly(1,2-butadiene) (PBD)', 'poly(orthoester) based on hexamethylenediol (POEHD)', 'poly(sebacic anhydride) (PSA)', 'poly(ether imide) (Kapton HN) (KAP)', 'poly(urea) (PUa)', 'poly(2,6-dimethyl-1,4-phenylene oxide) (PDMPO)', 'poly(vinylidine fluoride) (PVdF)', 'poly(glycidyl methacrylate) (PGMA)', 'poly(styrene-co-maleic anhydride) (PSCMA)', 'poly(4-vinylpyridine) (P4VP)', 'poly(4-bromostyrene) (PBS)', 'poly(glycolide) (PG)', 'poly(vinylbenzyltrimethylammonium chloride) (PVBTMAC)', 'poly(acrylic acid) (PAA)', 'poly(ethyl methacrylate) (PEMA)', 'poly(3-chlolorostyrene) (P3CS)', 'poly(ethylene glycol) (PEG)', 'cellulose (CEL)', 'Ethylcellulose (ECEL)', 'poly(N-vinylpyrrolidone) (PNVP)', 'poly(methacrylamide) (PMAM)', 'poly(methylene glycol) (PMG)']
# Material ID: ../data/experimental_data/poly(acrylamide) (PAM)/poly(acrylamide).xlsx
# Material ID: ../data/experimental_data/poly(tetrafluoroethylene) (PTFE)/poly(tetrafluoroethylene).xlsx
# Material ID: ../data/experimental_data/poly(hexamethylene sulphone) (PHMS)/poly(hexamethylene sulphone).xlsx
# Material ID: ../data/experimental_data/poly(ether sulphone) (PES)/poly(ether sulphone).xlsx
# Material ID: ../data/experimental_data/p-Quaterphenyl [poly(phenylene) oligomer]/p-Quaterphenyl [poly(phenylene) oligomer].xlsx
# Material ID: ../data/experimental_data/poly(methacrylonitrile) (PMAN)/poly(methacrylonitrile).xlsx
# Material ID: ../data/experimental_data/poly(propylene) (PP)/poly(propylene).xlsx
# Material ID: ../data/experimental_data/poly(ether imide) (Ultem 1000) (ULT)/poly(ether imide) (Ultem 1000).xlsx
# Material ID: ../data/experimental_data/Poly(2-chloroethyl methacrylate) (PCEMA)/Poly(2-chloroethyl methacrylate).xlsx
# Material ID: ../data/experimental_data/poly(vinyl methyl ether) (PVME)/poly(vinyl methyl ether).xlsx
# Material ID: ../data/experimental_data/poly(vinylidine chloride) (PVdC)/poly(vinylidine chloride).xlsx
# Material ID: ../data/experimental_data/poly(ethylene sulphide) (PETHS)/poly(ethylene sulphide).xlsx
# Material ID: ../data/experimental_data/poly(a-methylstryene) (PαMS)/poly(a-methylstryene).xlsx
# Material ID: ../data/experimental_data/poly(phenylene sulphide) (PPS)/poly(phenylene sulphide).xlsx
# Material ID: ../data/experimental_data/Nylon 6 (N6)/Nylon 6.xlsx
# Material ID: ../data/experimental_data/poly(2-ethyl-2-oxazoline) (PEOx)/poly(2-ethyl-2-oxazoline).xlsx
# Material ID: ../data/experimental_data/poly(propylene glycol) (PPG)/poly(propylene glycol).xlsx
# Material ID: ../data/experimental_data/poly(tert-butyl methacrylate) (PtBMA)/poly(tert-butyl methacrylate).xlsx
# Material ID: ../data/experimental_data/poly(phenoxyphosphazine) (PPP)/poly(phenoxyphosphazine).xlsx
# Material ID: ../data/experimental_data/poly(orthoester) based on trans-cyclohexanedimethanol (POECDM)/poly(orthoester) based on trans-cyclohexanedimethanol.xlsx
# Material ID: ../data/experimental_data/poly(methacrylic acid) (PMAA)/poly(methacrylic acid).xlsx
# Material ID: ../data/experimental_data/poly(methyl methacrylate) (PMMA)/poly(methyl methacrylate).xlsx
# Material ID: ../data/experimental_data/poly(d,l-lactide) (PL)/poly(d,l-lactide).xlsx
# Material ID: ../data/experimental_data/poly(caprolactone) (PCL)/poly(caprolactone).xlsx
# Material ID: ../data/experimental_data/poly(acrylonitrile) (PAN)/poly(acrylonitrile).xlsx
# Material ID: ../data/experimental_data/poly(allylamine hydrochloride) (PAAMC)/poly(allylamine hydrochloride).xlsx
# Material ID: ../data/experimental_data/poly(trifluoroethyl acrylate) (PTFEA)/poly(trifluoroethyl acrylate).xlsx
# Material ID: ../data/experimental_data/poly(vinyl alcohol) (PVA)/poly(vinyl alcohol).xlsx
# Material ID: ../data/experimental_data/poly(vinyl acetate) (PVAc)/poly(vinyl acetate).xlsx
# Material ID: ../data/experimental_data/poly(4-hydroxystyrene) (PHS)/poly(4-hydroxystyrene).xlsx
# Material ID: ../data/experimental_data/Nylon 6,6 (N66)/Nylon 6,6.xlsx
# Material ID: ../data/experimental_data/poly(tetramethylene glycol) (PTMG)/poly(tetramethylene glycol).xlsx
# Material ID: ../data/experimental_data/poly(methyl acrylate) (PMA)/poly(methyl acrylate).xlsx
# Material ID: ../data/experimental_data/poly(cis-butadiene) (PcBD)/poly(cis-butadiene).xlsx
# Material ID: ../data/experimental_data/poly(vinyl trifluoroacetate) (PVTFA)/poly(vinyl trifluoroacetate).xlsx
# Material ID: ../data/experimental_data/poly(ethylene terephthalate) (PET)/poly(ethylene terephthalate).xlsx
# Material ID: ../data/experimental_data/poly(diallyl isophthalate) (PDAiP)/poly(diallyl isophthalate).xlsx
# Material ID: ../data/experimental_data/N,N'-Diphenyl-1,4-phenylenediamine [poly(aniline) oligomer]/N,N'-Diphenyl-1,4-phenylenediamine [poly(aniline) oligomer].xlsx
# Material ID: ../data/experimental_data/poly(4-methyl-1-pentene) (PMP)/poly(4-methyl-1-pentene).xlsx
# Material ID: ../data/experimental_data/poly(4-methylstyrene) (P4MS)/poly(4-methylstyrene).xlsx
# Material ID: ../data/experimental_data/poly(2-vinylnaphthalene) (PVN)/poly(2-vinylnaphthalene).xlsx
# Material ID: ../data/experimental_data/poly(3-hydroxybutyrate) (PHB)/poly(3-hydroxybutyrate).xlsx
# Material ID: ../data/experimental_data/poly(n-butyl methacrylate) (PnBMA)/poly(n-butyl methacrylate).xlsx
# Material ID: ../data/experimental_data/poly(vinyl propionate) (PVP)/poly(vinyl propionate).xlsx
# Material ID: ../data/experimental_data/cellulose triacetate (CTA)/cellulose triacetate.xlsx
# Material ID: ../data/experimental_data/poly(ethyl acrylate) (PEA)/poly(ethyl acrylate).xlsx
# Material ID: ../data/experimental_data/poly(vinyl isobutyl ether) (PViBE)/poly(vinyl isobutyl ether).xlsx
# Material ID: ../data/experimental_data/poly(pheonylmethylsiloxane) (PPMS)/poly(pheonylmethylsiloxane).xlsx
# Material ID: ../data/experimental_data/poly(vinyl chloride) (PVC)/poly(vinyl chloride).xlsx
# Material ID: ../data/experimental_data/cellulose trinitrate (CTN)/cellulose trinitrate.xlsx
# Material ID: ../data/experimental_data/poly(vinyl ethyl ketone) (PVEK)/poly(vinyl ethyl ketone).xlsx
# Material ID: ../data/experimental_data/poly(vinyl laurate) (PVL)/poly(vinyl laurate).xlsx
# Material ID: ../data/experimental_data/poly(4-chlolorostyrene) (P4CS)/poly(4-chlolorostyrene).xlsx
# Material ID: ../data/experimental_data/poly(isobutylene) (PIB)/poly(isobutylene).xlsx
# Material ID: ../data/experimental_data/poly(4-methoxystyrene) (PMS)/poly(4-methoxystyrene).xlsx
# Material ID: ../data/experimental_data/poly(dimethylsiloxane) (PDMS)/poly(dimethylsiloxane).xlsx
# Material ID: ../data/experimental_data/poly(urethane) (PU)/poly(urethane).xlsx
# Material ID: ../data/experimental_data/poly(trans-isoprene) (PtI)/poly(trans-isoprene).xlsx
# Material ID: ../data/experimental_data/poly(lauryl methacrylate) (PLMA)/poly(lauryl methacrylate).xlsx
# Material ID: ../data/experimental_data/poly(chloroprene) (PCP)/poly(chloroprene).xlsx
# Material ID: ../data/experimental_data/poly(styrene) (PS)/poly(styrene).xlsx
# Material ID: ../data/experimental_data/poly(4-nitrostyrene) (PNS)/poly(4-nitrostyrene).xlsx
# Material ID: ../data/experimental_data/poly(ethylene adipate) (PEAd)/poly(ethylene adipate).xlsx
# Material ID: ../data/experimental_data/poly(vinyl methyl ketone) (PVMK)/poly(vinyl methyl ketone).xlsx
# Material ID: ../data/experimental_data/poly(2-vinylpyridine) (P2VP)/poly(2-vinylpyridine).xlsx
# Material ID: ../data/experimental_data/poly(bisphenol A carbonate) (PBAC)/poly(bisphenol A carbonate).xlsx
# Material ID: ../data/experimental_data/poly(9-vinylcarbazole) (P9VC)/poly(9-vinylcarbazole).xlsx
# Material ID: ../data/experimental_data/poly(vinyl ethyl ether) (PVEE)/poly(vinyl ethyl ether).xlsx
# Material ID: ../data/experimental_data/poly(hydroxyethyl methacrylate) (PHEMA)/poly(hydroxyethyl methacrylate).xlsx
# Material ID: ../data/experimental_data/poly(cis-isoprene) (PcI)/poly(cis-isoprene).xlsx
# Material ID: ../data/experimental_data/poly(ethylene-co-maleic anhydride) (PECMA)/poly(ethylene-co-maleic anhydride).xlsx
# Material ID: ../data/experimental_data/poly(ethyleneimine) (PEI)/poly(ethyleneimine).xlsx
# Material ID: ../data/experimental_data/poly(1-butene) (PB)/poly(1-butene).xlsx
# Material ID: ../data/experimental_data/poly(2-chlorostyrene) (P2CS)/poly(2-chlorostyrene).xlsx
# Material ID: ../data/experimental_data/poly(vinyl fluoride) (PVF)/poly(vinyl fluoride).xlsx
# Material ID: ../data/experimental_data/Nylon 12 (N12)/Nylon 12.xlsx
# Material ID: ../data/experimental_data/poly(acetylacetoxyethyl methacrylate) (PAAEMA)/poly(acetylacetoxyethyl methacrylate).xlsx
# Material ID: ../data/experimental_data/Hydroxypropylycellulose (HPCEL)/Hydroxypropylycellulose.xlsx
# Material ID: ../data/experimental_data/poly(sodium 4-styrenesulphonate) (PSS)/poly(sodium 4-styrenesulphonate).xlsx
# Material ID: ../data/experimental_data/poly(diallyl phthalate) (PDAP)/poly(diallyl phthalate).xlsx
# Material ID: ../data/experimental_data/poly(ether ether ketone) (PEEK)/poly(ether ether ketone).xlsx
# Material ID: ../data/experimental_data/poly(pivalolactone) (PPL)/poly(pivalolactone).xlsx
# Material ID: ../data/experimental_data/poly(methyl isopropenyl ketone) (PMIK)/poly(methyl isopropenyl ketone).xlsx
# Material ID: ../data/experimental_data/poly(ethylene), high density (HDPE)/poly(ethylene), high density.xlsx
# Material ID: ../data/experimental_data/poly(1,2-butadiene) (PBD)/poly(1,2-butadiene).xlsx
# Material ID: ../data/experimental_data/poly(orthoester) based on hexamethylenediol (POEHD)/poly(orthoester) based on hexamethylenediol.xlsx
# Material ID: ../data/experimental_data/poly(sebacic anhydride) (PSA)/poly(sebacic anhydride).xlsx
# Material ID: ../data/experimental_data/poly(ether imide) (Kapton HN) (KAP)/poly(ether imide) (Kapton HN).xlsx
# Material ID: ../data/experimental_data/poly(urea) (PUa)/poly(urea).xlsx
# Material ID: ../data/experimental_data/poly(2,6-dimethyl-1,4-phenylene oxide) (PDMPO)/poly(2,6-dimethyl-1,4-phenylene oxide).xlsx
# Material ID: ../data/experimental_data/poly(vinylidine fluoride) (PVdF)/poly(vinylidine fluoride).xlsx
# Material ID: ../data/experimental_data/poly(glycidyl methacrylate) (PGMA)/poly(glycidyl methacrylate).xlsx
# Material ID: ../data/experimental_data/poly(styrene-co-maleic anhydride) (PSCMA)/poly(styrene-co-maleic anhydride).xlsx
# Material ID: ../data/experimental_data/poly(4-vinylpyridine) (P4VP)/poly(4-vinylpyridine).xlsx
# Material ID: ../data/experimental_data/poly(4-bromostyrene) (PBS)/poly(4-bromostyrene).xlsx
# Material ID: ../data/experimental_data/poly(glycolide) (PG)/poly(glycolide).xlsx
# Material ID: ../data/experimental_data/poly(vinylbenzyltrimethylammonium chloride) (PVBTMAC)/poly(vinylbenzyltrimethylammonium chloride).xlsx
# Material ID: ../data/experimental_data/poly(acrylic acid) (PAA)/poly(acrylic acid).xlsx
# Material ID: ../data/experimental_data/poly(ethyl methacrylate) (PEMA)/poly(ethyl methacrylate).xlsx
# Material ID: ../data/experimental_data/poly(3-chlolorostyrene) (P3CS)/poly(3-chlolorostyrene).xlsx
# Material ID: ../data/experimental_data/poly(ethylene glycol) (PEG)/poly(ethylene glycol).xlsx
# Material ID: ../data/experimental_data/cellulose (CEL)/cellulose.xlsx
# Material ID: ../data/experimental_data/Ethylcellulose (ECEL)/Ethylcellulose.xlsx
# Material ID: ../data/experimental_data/poly(N-vinylpyrrolidone) (PNVP)/poly(N-vinylpyrrolidone).xlsx
# Material ID: ../data/experimental_data/poly(methacrylamide) (PMAM)/poly(methacrylamide).xlsx
# Material ID: ../data/experimental_data/poly(methylene glycol) (PMG)/poly(methylene glycol).xlsx

# %%
synth_spectra_dir = Path('../data/synthetic_data_full/synthetic_spectra')
synth_labels_dir = Path('../data/synthetic_data_full/synthetic_labels')

for i in range(data_size):
    spectra_csv = pd.DataFrame({'Spectra': spectra[i]})
    labels_csv = pd.DataFrame({'Labels': labels[i]})
    spectra_csv.to_csv(os.path.join(synth_spectra_dir, f'spectrum_{i}.csv'), index=False)
    labels_csv.to_csv(os.path.join(synth_labels_dir, f'label_{i}.csv'), index=False)

# %%
CEL_spec = os.path.join(data_path, 'cellulose (CEL)', 'cellulose') + '.xlsx'
df_f = pd.read_excel(CEL_spec, sheet_name='All')
binding_energy =  np.array(df_f['Binding Energy'][::-1])

for i in range(data_size):
    synth_spectra = pd.read_csv(os.path.join(synth_spectra_dir, f'spectrum_{i}.csv'))
    plt.plot(synth_spectra['Spectra'])

plt.xlabel('Binding Energy')
plt.ylabel('Intensity')
plt.show()
# Out:
# 2210
# Values in binding_energies are not evenly spaced intervals
# Range of intervals: min=0.09999999999990905, max=142.0
# Index of maximum spacing: 2028
# Indexes for all intervals greater than 0.1: (array([ 450,  751,  851, 1052, 1254, 1395, 1646, 1827, 2028]),)

# %%
print(len(binding_energy))
import numpy as np

# Check if values in binding_energies are evenly spaced intervals
spacing = np.diff(binding_energy)
if np.allclose(spacing, spacing[0]):
    print("Values in binding_energies are evenly spaced intervals")
    print(f"Range of intervals: min={np.min(spacing)}, max={np.max(spacing)}")
else:
    print("Values in binding_energies are not evenly spaced intervals")
    print(f"Range of intervals: min={np.min(spacing)}, max={np.max(spacing)}")
    max_spacing_index = np.argmax(spacing)
    print(f"Index of maximum spacing: {max_spacing_index}")
    # Print indexes for all intervals greater than 0.1 as a dataframe

    intervals_df = pd.DataFrame({'Index': np.where(spacing > 0.11)[0], 'Interval': spacing[spacing > 0.11], 'Binding Energy': binding_energy[np.where(spacing > 0.11)[0]]})
    print(intervals_df)
# Out:
# 2210
# Values in binding_energies are not evenly spaced intervals
# Range of intervals: min=0.09999999999990905, max=142.0
# Index of maximum spacing: 2028
#    Index  Interval  Binding Energy
# 0    450      20.0            40.0
# 1    751       7.4            90.0
# 2    851      21.0           107.3
# 3   1052      12.7           148.3
# 4   1254      14.9           181.1
# 5   1395      65.0           210.0
# 6   1646      92.0           300.0
# 7   1827     110.0           410.0
# 8   2028     142.0           540.0

# %% [markdown]
# # Troubleshooting Tools

# %% [markdown]
# plot overlay of all synthetic spectra:

# %%
CEL_spec = os.path.join(data_path, 'cellulose (CEL)', 'cellulose') + '.xlsx'
df_f = pd.read_excel(CEL_spec, sheet_name='All')
binding_energy =  np.array(df_f['Binding Energy'])
binding_energy_section = binding_energy[0:2210]

for i in range(5):
    plt.plot(binding_energy_section, spectra[i])
    plt.xlabel('Binding Energy')
    plt.ylabel('Intensity')

plt.savefig('generated_xps_overlay')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(spectra[4])
plt.xlabel('Binding Energy')
plt.ylabel('Intensity')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.plot(spectra[4])
#       2 plt.xlabel('Binding Energy')
#       3 plt.ylabel('Intensity')
#
# NameError: name 'plt' is not defined

# %%
for i in range(data_size):
    if len(spectra[i]) != 2210:
        print(len(spectra[i]))

# %% [markdown]
# Plot all original spectra:

# %%
for i in range(len(xps_data[2])):
    plt.plot(binding_energy_section, xps_data[0][xps_data[2][i][:2210]])

# %%
import scipy

def apply_horizontal_shift(spectrum, max_shift):
    '''
    Applies a random horizontal shift to the entire spectrum sequence.
    Args:
        spectrum
        max_shift: maximum number of indices by which the data can shift (set to zero for no shift allowed)
    Returns:
        shifted_spectrum
    '''
    shift = random.randint(-max_shift, max_shift)
    # Create an array of zeros with the same length as the original spectrum
    shifted_spectrum = np.zeros_like(spectrum)

    if shift > 0:
        # Shift to the right
        shifted_spectrum[shift:] = spectrum[:-shift]
    elif shift < 0:
        # Shift to the left
        shifted_spectrum[:shift] = spectrum[-shift:]
    else:
        # No shift, return the original spectrum
        shifted_spectrum = spectrum.copy()

    shifted_spectrum = shifted_spectrum[:len(spectrum)]
    return shifted_spectrum

def gaussian_broadening(spectrum, sigma):
    # Broaden the entire spectrum
    x = np.linspace(-3*sigma, 3*sigma, len(spectrum))
    gaussian = np.exp(-(x/sigma)**2/2)
    broadened_spectrum = np.convolve(spectrum, gaussian, mode='same')
    
    return broadened_spectrum


def all_effects(spectrum):
    out_put_spectrum = apply_horizontal_shift(gaussian_broadening(spectrum))
    return out_put_spectrum


max_shift = 100
test = xps_data[0][xps_data[2][3]]
new_plot = gaussian_broadening(test, max_shift)

plt.plot(test)
plt.plot(new_plot[0])
print(new_plot[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only length-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 53
#      51 max_shift = 100
#      52 test = xps_data[0][xps_data[2][3]]
# ---> 53 new_plot = gaussian_broadening(test, max_shift)
#      55 plt.plot(test)
#      56 plt.plot(new_plot[0])
#
# Cell In[73], line 41, in gaussian_broadening(spectrum, sigma)
#      39     peak = spectrum[peak_index]
#      40     broadened_peak = np.convolve(peak, gaussian, mode='same')
# ---> 41     broadened_spectrum[peak_index] = broadened_peak
#      43 return broadened_spectrum
#
# ValueError: setting an array element with a sequence.

# %% [markdown]
# Save example plots of generated synthetic spectra:

# %%
CEL_spec = os.path.join(data_path, 'cellulose (CEL)', 'cellulose') + '.xlsx'
df_f = pd.read_excel(CEL_spec, sheet_name='All')
binding_energy =  np.array(df_f['Binding Energy'])
binding_energy_section = binding_energy[0:2210]
plots_dir = Path( '../data/synth_plots_examples')

for i in range(21):
    plt.plot(binding_energy_section,spectra[i])
    # Get the label and display it in a box
    label_text = label_converter(labels[i])

    if not label_text:
        box = 'no functional groups'
    else:
        box = "\n".join(label_text)
        
    plt.text(0.95, 0.95, box, 
             ha='right', va='top',  # Horizontal and vertical alignment
             fontsize=10, 
             bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'),  # Box around text
             transform=plt.gca().transAxes)  # Place box in top right

    plt.xlabel('Binding Energy')
    plt.ylabel('Intensity')

    plt.savefig(os.path.join(plots_dir, 'spectrum_{}.png'.format(i)))
    plt.clf()

# %% [markdown]
# investigate individual synthetic spectrum:

# %%
CEL_spec = os.path.join(data_path, 'cellulose (CEL)', 'cellulose') + '.xlsx'
df_f = pd.read_excel(CEL_spec, sheet_name='All')
binding_energy =  np.array(df_f['Binding Energy'])
binding_energy_section = binding_energy[5:1600]

i = 12

plt.plot(binding_energy_section, spectra[i])
# Get the label and display it in a box
label_text = label_converter(labels[i])

if not label_text:
    box = 'no functional groups'
else:
    box = "\n".join(label_text)
        
plt.text(0.95, 0.95, box, 
         ha='right', va='top',  # Horizontal and vertical alignment
         fontsize=10, 
         bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'),  # Box around text
         transform=plt.gca().transAxes)  # Place box in top right

plt.xlabel('Binding Energy')
plt.ylabel('Intensity')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 8
#       4 binding_energy_section = binding_energy[5:1600]
#       6 i = 12
# ----> 8 plt.plot(binding_energy_section, spectra[i])
#       9 # Get the label and display it in a box
#      10 label_text = label_converter(labels[i])
#
# File ~/GenXPS/genXPS/.venv/lib/python3.12/site-packages/matplotlib/pyplot.py:3794, in plot(scalex, scaley, data, *args, **kwargs)
#    3786 @_copy_docstring_and_deprecators(Axes.plot)
#    3787 def plot(
#    3788     *args: float | ArrayLike | str,
#    (...)
#    3792     **kwargs,
#    3793 ) -> list[Line2D]:
# -> 3794     return gca().plot(
#    3795         *args,
#    3796         scalex=scalex,
#    3797         scaley=scaley,
#    3798         **({"data": data} if data is not None else {}),
#    3799         **kwargs,
#    3800     )
#
# File ~/GenXPS/genXPS/.venv/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
#    1781     self.add_line(line)
#
# File ~/GenXPS/genXPS/.venv/lib/python3.12/site-packages/matplotlib/axes/_base.py:296, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     294     this += args[0],
#     295     args = args[1:]
# --> 296 yield from self._plot_args(
#     297     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/GenXPS/genXPS/.venv/lib/python3.12/site-packages/matplotlib/axes/_base.py:486, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     483     axes.yaxis.update_units(y)
#     485 if x.shape[0] != y.shape[0]:
# --> 486     raise ValueError(f"x and y must have same first dimension, but "
#     487                      f"have shapes {x.shape} and {y.shape}")
#     488 if x.ndim > 2 or y.ndim > 2:
#     489     raise ValueError(f"x and y can be no greater than 2D, but have "
#     490                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (1595,) and (2210,)

# %% [markdown]
# check for synthetic specra containing no functional groups:

# %%
for i, label in enumerate(labels): 
    if all(v == 0 for v in label):
        print(f"Index {i}: All zeros")

        plt.plot(spectra[i])
        # Get the label and display it in a box
        label_text = label_converter(labels[i])

        if not label_text:
            box = 'no functional groups'
        else:
            box = "\n".join(label_text)
            
        plt.text(0.95, 0.95, box, 
                ha='right', va='top',  # Horizontal and vertical alignment
                fontsize=10, 
                bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'),  # Box around text
                transform=plt.gca().transAxes)  # Place box in top right

plt.show()
# Out:
# Index 98: All zeros
# Index 114: All zeros
# Index 136: All zeros
# Index 172: All zeros
# Index 194: All zeros

# %% [markdown]
# Practice accessing files based off folder/file names:

# %%
elements = None
data_path = "/root/GenXPS/genXPS/data/experimental_data"

if not elements:
        all_folders = os.listdir(data_path)
else:
        all_folders = [e for e in elements]

format_exceptions = ("N,N'-Diphenyl-1,4-phenylenediamine [poly(aniline) oligomer]", "p-Quaterphenyl [poly(phenylene) oligomer]", "poly(tetrafluoroethylene)" )
spectral_data = {}
label_data = {}
ids = []
print('Folders', all_folders)
for folder in all_folders:
    folder_spec_format = folder[:folder.rfind(' (')]
    folder_label_format = folder[folder.rfind(' (') + 2:folder.rfind(')')]

    filename_spec = folder_spec_format + '.xlsx'
    filename_label = folder_label_format + '_FG.xlsx'

    spec_path = os.path.join(data_path, folder, filename_spec)
    label_path = os.path.join(data_path, folder, filename_label)

    if not os.path.isfile(label_path):
        filename_label = folder + '_FG.xlsx'
        label_path = os.path.join(data_path, folder, filename_label)
            
    if not os.path.isfile(spec_path):
        filename_spec = folder + '.xlsx'
        spec_path = os.path.join(data_path, folder, filename_spec)

    if not os.path.isfile(label_path):
        print(print(f"Warning: {folder} does not contain {filename_label}"))
    if not os.path.isfile(spec_path):
        print(f"Warning: {folder} does not contain {filename_spec}")
# Out:
# Folders ['poly(acrylamide) (PAM)', 'poly(tetrafluoroethylene) (PTFE)', 'poly(hexamethylene sulphone) (PHMS)', 'poly(ether sulphone) (PES)', 'p-Quaterphenyl [poly(phenylene) oligomer]', 'poly(methacrylonitrile) (PMAN)', 'poly(propylene) (PP)', 'poly(ether imide) (Ultem 1000) (ULT)', 'Poly(2-chloroethyl methacrylate) (PCEMA)', 'poly(vinyl methyl ether) (PVME)', 'poly(vinylidine chloride) (PVdC)', 'poly(ethylene sulphide) (PETHS)', 'poly(a-methylstryene) (PαMS)', 'poly(phenylene sulphide) (PPS)', 'Nylon 6 (N6)', 'poly(2-ethyl-2-oxazoline) (PEOx)', 'poly(propylene glycol) (PPG)', 'poly(tert-butyl methacrylate) (PtBMA)', 'poly(phenoxyphosphazine) (PPP)', 'poly(orthoester) based on trans-cyclohexanedimethanol (POECDM)', 'poly(methacrylic acid) (PMAA)', 'poly(methyl methacrylate) (PMMA)', 'poly(d,l-lactide) (PL)', 'poly(caprolactone) (PCL)', 'poly(acrylonitrile) (PAN)', 'poly(allylamine hydrochloride) (PAAMC)', 'poly(trifluoroethyl acrylate) (PTFEA)', 'poly(vinyl alcohol) (PVA)', 'poly(vinyl acetate) (PVAc)', 'poly(4-hydroxystyrene) (PHS)', 'Nylon 6,6 (N66)', 'poly(tetramethylene glycol) (PTMG)', 'poly(methyl acrylate) (PMA)', 'poly(cis-butadiene) (PcBD)', 'poly(vinyl trifluoroacetate) (PVTFA)', 'poly(ethylene terephthalate) (PET)', 'poly(diallyl isophthalate) (PDAiP)', "N,N'-Diphenyl-1,4-phenylenediamine [poly(aniline) oligomer]", 'poly(4-methyl-1-pentene) (PMP)', 'poly(4-methylstyrene) (P4MS)', 'poly(2-vinylnaphthalene) (PVN)', 'poly(3-hydroxybutyrate) (PHB)', 'poly(n-butyl methacrylate) (PnBMA)', 'poly(vinyl propionate) (PVP)', 'cellulose triacetate (CTA)', 'poly(ethyl acrylate) (PEA)', 'poly(vinyl isobutyl ether) (PViBE)', 'poly(pheonylmethylsiloxane) (PPMS)', 'poly(vinyl chloride) (PVC)', 'cellulose trinitrate (CTN)', 'poly(vinyl ethyl ketone) (PVEK)', 'poly(vinyl laurate) (PVL)', 'poly(4-chlolorostyrene) (P4CS)', 'poly(isobutylene) (PIB)', 'poly(4-methoxystyrene) (PMS)', 'poly(dimethylsiloxane) (PDMS)', 'poly(urethane) (PU)', 'poly(trans-isoprene) (PtI)', 'poly(lauryl methacrylate) (PLMA)', 'poly(chloroprene) (PCP)', 'poly(styrene) (PS)', 'poly(4-nitrostyrene) (PNS)', 'poly(ethylene adipate) (PEAd)', 'poly(vinyl methyl ketone) (PVMK)', 'poly(2-vinylpyridine) (P2VP)', 'poly(bisphenol A carbonate) (PBAC)', 'poly(9-vinylcarbazole) (P9VC)', 'poly(vinyl ethyl ether) (PVEE)', 'poly(hydroxyethyl methacrylate) (PHEMA)', 'poly(cis-isoprene) (PcI)', 'poly(ethylene-co-maleic anhydride) (PECMA)', 'poly(ethyleneimine) (PEI)', 'poly(1-butene) (PB)', 'poly(2-chlorostyrene) (P2CS)', 'poly(vinyl fluoride) (PVF)', 'Nylon 12 (N12)', 'poly(acetylacetoxyethyl methacrylate) (PAAEMA)', 'Hydroxypropylycellulose (HPCEL)', 'poly(sodium 4-styrenesulphonate) (PSS)', 'poly(diallyl phthalate) (PDAP)', 'poly(ether ether ketone) (PEEK)', 'poly(pivalolactone) (PPL)', 'poly(methyl isopropenyl ketone) (PMIK)', 'poly(ethylene), high density (HDPE)', 'poly(1,2-butadiene) (PBD)', 'poly(orthoester) based on hexamethylenediol (POEHD)', 'poly(sebacic anhydride) (PSA)', 'poly(ether imide) (Kapton HN) (KAP)', 'poly(urea) (PUa)', 'poly(2,6-dimethyl-1,4-phenylene oxide) (PDMPO)', 'poly(vinylidine fluoride) (PVdF)', 'poly(glycidyl methacrylate) (PGMA)', 'poly(styrene-co-maleic anhydride) (PSCMA)', 'poly(4-vinylpyridine) (P4VP)', 'poly(4-bromostyrene) (PBS)', 'poly(glycolide) (PG)', 'poly(vinylbenzyltrimethylammonium chloride) (PVBTMAC)', 'poly(acrylic acid) (PAA)', 'poly(ethyl methacrylate) (PEMA)', 'poly(3-chlolorostyrene) (P3CS)', 'poly(ethylene glycol) (PEG)', 'cellulose (CEL)', 'Ethylcellulose (ECEL)', 'poly(N-vinylpyrrolidone) (PNVP)', 'poly(methacrylamide) (PMAM)', 'poly(methylene glycol) (PMG)']
